# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("D:\python\salary\survey_results_public.csv")
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\palla\AppData\Local\Temp\ipykernel_16916\1504981925.py:1: SyntaxWarning: invalid escape sequence '\p'
#   df=pd.read_csv("D:\python\salary\survey_results_public.csv")
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# ...

# %%
df=df[["Country","EdLevel","YearsCodePro","Employment","ConvertedComp"]]
df=df.rename({"ConvertedComp":"Salary"},axis=1)
df
# Out:
#                   Country                                          EdLevel  \
# 0                 Germany  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1          United Kingdom     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2      Russian Federation                                              NaN
# 3                 Albania  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4           United States     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                   ...                                              ...
# 64456       United States  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64457             Morocco                                              NaN
# 64458            Viet Nam                        Primary/elementary school
# 64459              Poland                                              NaN
# 64460               Spain       Other doctoral degree (Ph.D., Ed.D., etc.)
#
# ...

# %%
df=df[df["Salary"].notnull()]
df
# Out:
#               Country                                            EdLevel  \
# 7       United States       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9      United Kingdom    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 10     United Kingdom       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 11              Spain  Some college/university study without earning ...
# 12        Netherlands  Secondary school (e.g. American high school, G...
# ...               ...                                                ...
# 64142         Nigeria  Secondary school (e.g. American high school, G...
# 64148        Colombia       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64152   United States  Some college/university study without earning ...
# 64153           Chile       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64154           Japan       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#            YearsCodePro          Employment    Salary
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34756 entries, 7 to 64154
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       34756 non-null  object
#  1   EdLevel       34188 non-null  object
#  2   YearsCodePro  34621 non-null  object
#  3   Employment    34717 non-null  object
#  4   Salary        34756 non-null  float64
# dtypes: float64(1), object(4)
# memory usage: 1.6+ MB

# %%
df.isnull().sum()
# Out:
# Country           0
# EdLevel         568
# YearsCodePro    135
# Employment       39
# Salary            0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Country         0
# EdLevel         0
# YearsCodePro    0
# Employment      0
# Salary          0
# dtype: int64

# %%
df
# Out:
#               Country                                            EdLevel  \
# 7       United States       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9      United Kingdom    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 10     United Kingdom       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 11              Spain  Some college/university study without earning ...
# 12        Netherlands  Secondary school (e.g. American high school, G...
# ...               ...                                                ...
# 64142         Nigeria  Secondary school (e.g. American high school, G...
# 64148        Colombia       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64152   United States  Some college/university study without earning ...
# 64153           Chile       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64154           Japan       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#            YearsCodePro          Employment    Salary
# ...

# %%
df=df[df["Employment"]=="Employed full-time"]
df
# Out:
#               Country                                            EdLevel  \
# 7       United States       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9      United Kingdom    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 10     United Kingdom       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 11              Spain  Some college/university study without earning ...
# 12        Netherlands  Secondary school (e.g. American high school, G...
# ...               ...                                                ...
# 64135         Denmark       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64148        Colombia       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64152   United States  Some college/university study without earning ...
# 64153           Chile       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64154           Japan       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#            YearsCodePro          Employment    Salary
# ...

# %%
df=df.drop("Employment",axis=1)
df
# Out:
#               Country                                            EdLevel  \
# 7       United States       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9      United Kingdom    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 10     United Kingdom       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 11              Spain  Some college/university study without earning ...
# 12        Netherlands  Secondary school (e.g. American high school, G...
# ...               ...                                                ...
# 64135         Denmark       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64148        Colombia       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64152   United States  Some college/university study without earning ...
# 64153           Chile       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64154           Japan       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#            YearsCodePro    Salary
# 7                    13  116000.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30019 entries, 7 to 64154
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       30019 non-null  object
#  1   EdLevel       30019 non-null  object
#  2   YearsCodePro  30019 non-null  object
#  3   Salary        30019 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 1.1+ MB

# %%
df['Country'].value_counts()
# Out:
# Country
# United States     7569
# India             2425
# United Kingdom    2287
# Germany           1903
# Canada            1178
#                   ...
# Swaziland            1
# Niger                1
# Belize               1
# Yemen                1
# Andorra              1
# Name: count, Length: 154, dtype: int64

# %%
def shorten_categories(categories,cutoff):
    categorical_map={}

    for i in range(len(categories)):
        if categories.values[i]>= cutoff:
            categorical_map[categories.index[i]]=categories.index[i]
        else:
            categorical_map[categories.index[i]]="Other"
    return categorical_map

# %%
country_map=shorten_categories(df['Country'].value_counts(),400)
country_map
# Out:
# {'United States': 'United States',
#  'India': 'India',
#  'United Kingdom': 'United Kingdom',
#  'Germany': 'Germany',
#  'Canada': 'Canada',
#  'Brazil': 'Brazil',
#  'France': 'France',
#  'Spain': 'Spain',
#  'Australia': 'Australia',
#  'Netherlands': 'Netherlands',
#  'Poland': 'Poland',
#  'Italy': 'Italy',
#  'Russian Federation': 'Russian Federation',
#  'Sweden': 'Sweden',
#  'Turkey': 'Other',
#  'Israel': 'Other',
#  'Pakistan': 'Other',
#  'Switzerland': 'Other',
#  'Mexico': 'Other',
#  'Ireland': 'Other',
#  'Norway': 'Other',
#  'Ukraine': 'Other',
#  'Romania': 'Other',
#  'South Africa': 'Other',
#  'Czech Republic': 'Other',
#  'Austria': 'Other',
#  'Belgium': 'Other',
#  'Iran': 'Other',
#  'Portugal': 'Other',
#  'Denmark': 'Other',
#  'Finland': 'Other',
#  'Argentina': 'Other',
#  'Hungary': 'Other',
#  'New Zealand': 'Other',
#  'Greece': 'Other',
#  'Japan': 'Other',
#  'Bulgaria': 'Other',
#  'Bangladesh': 'Other',
#  'Colombia': 'Other',
# ...

# %%
df['Country' ] = df['Country'].map(country_map)

df['Country'].value_counts()
# Out:
# Country
# Other                 8549
# United States         7569
# India                 2425
# United Kingdom        2287
# Germany               1903
# Canada                1178
# Brazil                 991
# France                 972
# Spain                  670
# Australia              659
# Netherlands            654
# Poland                 566
# Italy                  560
# Russian Federation     522
# Sweden                 514
# Name: count, dtype: int64

# %%
df
# Out:
#               Country                                            EdLevel  \
# 7       United States       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9      United Kingdom    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 10     United Kingdom       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 11              Spain  Some college/university study without earning ...
# 12        Netherlands  Secondary school (e.g. American high school, G...
# ...               ...                                                ...
# 64135           Other       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64148           Other       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64152   United States  Some college/university study without earning ...
# 64153           Other       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64154           Other       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#            YearsCodePro    Salary
# 7                    13  116000.0
# ...

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
df.boxplot('Salary', 'Country', ax= ax)
plt.suptitle('Salary (US$) vs Country')
plt.title('')
plt.ylabel("Salary")
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df=df[df['Salary'] <= 250000]
df=df[df['Salary'] >= 10000]
df=df[df['Country'] != 'Other']

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
df.boxplot('Salary', 'Country', ax= ax)
plt.suptitle('Salary (US$) vs Country')
plt.title('')
plt.ylabel("Salary")
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df["YearsCodePro"].unique()
# Out:
# array(['13', '4', '2', '7', '20', '1', '3', '10', '12', '29', '6', '28',
#        '8', '23', '15', '25', '9', '11', 'Less than 1 year', '5', '21',
#        '16', '18', '14', '32', '19', '22', '38', '30', '26', '27', '17',
#        '24', '34', '35', '33', '36', '40', '39', 'More than 50 years',
#        '31', '37', '41', '45', '42', '44', '43', '50', '49'], dtype=object)

# %%
def clean_experience(exp):
    if exp == "More than 50 years":
        return 50
    if exp == "Less than 1 year":
        return 0.5
    return float(exp)

df["YearsCodePro"] = df["YearsCodePro"].apply(clean_experience)

# %%
df["YearsCodePro"].unique()
# Out:
# array([13. ,  4. ,  2. ,  7. , 20. ,  1. ,  3. , 10. , 12. , 29. ,  6. ,
#        28. ,  8. , 23. , 15. , 25. ,  9. , 11. ,  0.5,  5. , 21. , 16. ,
#        18. , 14. , 32. , 19. , 22. , 38. , 30. , 26. , 27. , 17. , 24. ,
#        34. , 35. , 33. , 36. , 40. , 39. , 50. , 31. , 37. , 41. , 45. ,
#        42. , 44. , 43. , 49. ])

# %%
df['EdLevel'].unique()
# Out:
# array(['Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
#        'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
#        'Some college/university study without earning a degree',
#        'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#        'Associate degree (A.A., A.S., etc.)',
#        'Professional degree (JD, MD, etc.)',
#        'Other doctoral degree (Ph.D., Ed.D., etc.)',
#        'I never completed any formal education',
#        'Primary/elementary school'], dtype=object)

# %%
def clean_education(edu):
    if 'Bachelor’s degree' in edu:
        return 'Bachelors degree'
    elif 'Master’s degree' in edu:
        return 'Masters degree'
    elif 'Professional degree' in edu or 'other doctoral degree' in edu:
        return 'Post grad'
    return 'Less than a Bachelors'

df["EdLevel"]=df["EdLevel"].apply(clean_education)

# %%
df['EdLevel'].unique()
# Out:
# array(['Bachelors degree', 'Masters degree', 'Less than a Bachelors',
#        'Post grad'], dtype=object)

# %%
df
# Out:
#               Country                EdLevel  YearsCodePro    Salary
# 7       United States       Bachelors degree          13.0  116000.0
# 9      United Kingdom         Masters degree           4.0   32315.0
# 10     United Kingdom       Bachelors degree           2.0   40070.0
# 11              Spain  Less than a Bachelors           7.0   14268.0
# 12        Netherlands  Less than a Bachelors          20.0   38916.0
# ...               ...                    ...           ...       ...
# 64113   United States  Less than a Bachelors          15.0  225000.0
# 64116   United States       Bachelors degree           6.0  150000.0
# 64122   United States  Less than a Bachelors           4.0   70000.0
# 64127   United States  Less than a Bachelors          12.0  140000.0
# 64129   United States         Masters degree           4.0  150000.0
#
# [18491 rows x 4 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_education=LabelEncoder()
df['EdLevel']=le_education.fit_transform(df['EdLevel'])

# %%
df['EdLevel'].unique()
# Out:
# array([0, 2, 1, 3])

# %%
df
# Out:
#               Country  EdLevel  YearsCodePro    Salary
# 7       United States        0          13.0  116000.0
# 9      United Kingdom        2           4.0   32315.0
# 10     United Kingdom        0           2.0   40070.0
# 11              Spain        1           7.0   14268.0
# 12        Netherlands        1          20.0   38916.0
# ...               ...      ...           ...       ...
# 64113   United States        1          15.0  225000.0
# 64116   United States        0           6.0  150000.0
# 64122   United States        1           4.0   70000.0
# 64127   United States        1          12.0  140000.0
# 64129   United States        2           4.0  150000.0
#
# [18491 rows x 4 columns]

# %%
le_country=LabelEncoder()
df['Country']=le_country.fit_transform(df['Country'])
df
# Out:
#        Country  EdLevel  YearsCodePro    Salary
# 7           13        0          13.0  116000.0
# 9           12        2           4.0   32315.0
# 10          12        0           2.0   40070.0
# 11          10        1           7.0   14268.0
# 12           7        1          20.0   38916.0
# ...        ...      ...           ...       ...
# 64113       13        1          15.0  225000.0
# 64116       13        0           6.0  150000.0
# 64122       13        1           4.0   70000.0
# 64127       13        1          12.0  140000.0
# 64129       13        2           4.0  150000.0
#
# [18491 rows x 4 columns]

# %%
df['Country'].unique()
# Out:
# array([13, 12, 10,  7,  4,  2,  6,  1,  3,  5, 11,  8,  0,  9])

# %%
X=df.drop("Salary",axis=1)
Y=df["Salary"]

# %%
X,Y
# Out:
# (       Country  EdLevel  YearsCodePro
#  7           13        0          13.0
#  9           12        2           4.0
#  10          12        0           2.0
#  11          10        1           7.0
#  12           7        1          20.0
#  ...        ...      ...           ...
#  64113       13        1          15.0
#  64116       13        0           6.0
#  64122       13        1           4.0
#  64127       13        1          12.0
#  64129       13        2           4.0
#
#  [18491 rows x 3 columns],
#  7        116000.0
#  9         32315.0
#  10        40070.0
#  11        14268.0
#  12        38916.0
#             ...
#  64113    225000.0
#  64116    150000.0
#  64122     70000.0
#  64127    140000.0
#  64129    150000.0
#  Name: Salary, Length: 18491, dtype: float64)

# %% [markdown]
# MODEL TRAINING

# %% [markdown]
# 1. LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np

linear_reg = LinearRegression()
linear_reg.fit(X,Y.values)
# Out:
# LinearRegression()

# %%
y_pred=linear_reg.predict(X)

# %%
error=np.sqrt(mean_squared_error(Y,y_pred))
error
# Out:
# np.float64(39253.21049734323)

# %% [markdown]
# 2. Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

decision_tree= DecisionTreeRegressor()
decision_tree.fit(X,Y.values)
# Out:
# DecisionTreeRegressor()

# %%
y_pred_dec=decision_tree.predict(X)

# %%
error=np.sqrt(mean_squared_error(Y,y_pred_dec))
error
# Out:
# np.float64(29687.48762585127)

# %% [markdown]
# 3. Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

Random_forest=RandomForestRegressor()
Random_forest.fit(X,Y.values)
# Out:
# RandomForestRegressor()

# %%
y_pred_ran=Random_forest.predict(X)

# %%
error=np.sqrt(mean_squared_error(Y,y_pred_ran))
error
# Out:
# np.float64(29746.24865248718)

# %%
X=np.array([["United States","Masters degree",15]])
X
# Out:
# array([['United States', 'Masters degree', '15']], dtype='<U21')

# %%
X[:,0]=le_country.transform(X[:,0])
X[:,1] = le_education.transform(X[:,1])
X=X.astype(float)
X
# Out:
# array([[13.,  2., 15.]])

# %%
y_pred=decision_tree.predict(X)
y_pred
# Out:
# c:\Users\palla\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([146432.08510638])

# %% [markdown]
# SERIALIZING OR PICKLING

# %%
import pickle

# %%
data = {"model": decision_tree, "le_country":le_country,"le_education":le_education}

with open("saved_steps.pkl","wb") as f:
    pickle.dump(data,f)

# %%
pip install streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
